# %%
a = [1,2,3]
b = {"mike":a}

# %%
b
# Out:
# {'mike': [1, 2, 3]}

# %%
b["mike"]
# Out:
# [1, 2, 3]

# %%
type(b["mike"])
# Out:
# list

# %%
import json
c = json.dumps(b)
c
# Out:
# '{"mike": [1, 2, 3]}'

# %%
type(c)
# Out:
# str

# %%
d = json.loads(c)

# %%
d
# Out:
# {'mike': [1, 2, 3]}

# %%
type(d)
# Out:
# dict

# %%
l_stock = ['AAV', 'ADVANC', 'AEONTS', 'AMATA', 'ANAN', 'AOT', 'AP', 'BANPU', 'BBL', 'BCH', 'BCP', 'BCPG', 'BDMS', 'BEAUTY', 'BEC', 'BEM', 'BGRIM', 'BH', 'BJC', 'BLAND', 'BPP', 'BTS', 'CBG', 'CENTEL', 'CHG', 'CK', 'CKP', 'COM7', 'CPALL', 'CPF', 'CPN', 'DELTA', 'DTAC', 'EA', 'EGCO', 'EPG', 'ERW', 'ESSO', 'GFPT', 'GLOBAL', 'GOLD', 'GPSC', 'GULF', 'GUNKUL', 'HANA', 'HMPRO', 'INTUCH', 'IRPC', 'IVL', 'KBANK', 'KCE', 'KKP', 'KTB', 'KTC', 'LH', 'MAJOR', 'MBK', 'MEGA', 'MINT', 'MTC', 'ORI', 'PLANB', 'PRM', 'PSH', 'PSL', 'PTG', 'PTT', 'PTTEP', 'PTTGC', 'QH', 'RATCH', 'ROBINS', 'RS', 'SAWAD', 'SCB', 'SCC', 'SGP', 'SIRI', 'SPALI', 'SPRC', 'STA', 'STEC', 'SUPER', 'TASCO', 'TCAP', 'THAI', 'THANI', 'TISCO', 'TKN', 'TMB', 'TOA', 'TOP', 'TPIPP', 'TRUE', 'TTW', 'TU', 'TVO', 'WHA', 'WHAUP', 'WORK']

# %%
len(l_stock)
# Out:
# 100

# %%
txt = input("Type something to test this out: ")
print("Is this what you just said? ", txt)
# Out:
# Type something to test this out: 123
# Is this what you just said?  123

# %%
type(txt)
# Out:
# str

# %%
txt
# Out:
# '123'

# %%
import urllib.request

fp = urllib.request.urlopen("https://www.set.or.th/set/companyfinance.do?symbol=AAV&language=th&country=TH&type=balance")
mybytes = fp.read()

mystr = mybytes.decode("utf8")
fp.close()

print(mystr)
# Out:
# <!DOCTYPE html>
# <html lang="th">
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="th"> <![endif]-->
# <!--[if IE 7]> <html class="no-js lt-ie9 lt-ie8" lang="th"> <![endif]-->
# <!--[if IE 8]> <html class="no-js lt-ie9" lang="th"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="th"> <!--<![endif]-->
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1,IE=8">
#     <meta name="description" content="The Stock Exchange of Thailand: Your Investment Resource for Thailand's Capital Market">
#     <meta name="keywords" content="SET, mai, thai stocks, Thailand, stock, stock exchange, Thai capital market, equity, bond, derivatives, stock market, quotes, financial, internet trading, listed companies, IPO, regulations, broker, market data, investment information, news, investor education">
#     <meta name="viewport" content="width=device-width, initial-scale=1, user-scalable=yes">
#
#
#
#     <title>ตลาดหลักทรัพย์แห่งประเทศไทย - ข้อมูลรายบริษัท/หลักทรัพย์</title>
#
#     <link rel="shortcut icon" href="/images/favicon.ico" type="image/vnd.microsoft.icon" />
#     <link rel="stylesheet" href="/styles/bootstrap.min.css">
#     <link rel="stylesheet" href="/styles/bootstrap-theme.min.css">
#     <link rel="stylesheet" href="/styles/font-awesome.min.css">
#     <link rel="stylesheet" href="/styles/bootstrap-submenu.min.css">
#     <link rel="stylesheet" href="/styles/main.css">
#     <link rel="stylesheet" href="/styles/main-en.css">
#     <link rel="stylesheet" href="/styles/setstyle.css">
#     <link rel="stylesheet" href="/styles/main-responsive.css">
#     <link rel="stylesheet" href="/styles/tablet.css">
#     <link rel="stylesheet" href="/scripts/fullcalendar-2.1.1/fullcalendar.min.css">
#     <!--[if lt IE 10]><link rel="stylesheet" href="/styles/ie.css"> <![endif]-->
#     <script src="/scripts/vendor/jquery-1.11.2.min.js"></script>
#     <!-- Start Other CSS -->
#     <!-- Start Chart CSS -->
#     <link rel="stylesheet" href="/styles/chart.css">
#     <!-- End Chart CSS -->
#     <!-- End Other CSS -->
#     <!--[if lt IE 9]>
#     <script src="/scripts/vendor/html5shiv.min.js"></script>
#     <script src="/scripts/vendor/modernizr-2.6.2-respond-1.1.0.min.js"></script>
#     <![endif]-->
#
#
#
#
# <script>
#     dataLayer = [{"content_group":"company"}];
# </script>
#
#
#
#     <!-- Facebook Pixel Code -->
# <script>
# 	!function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# 			n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# 		n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# 		t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# 			document,'script','https://connect.facebook.net/en_US/fbevents.js');
#
# 	fbq('init', '1613758345606983');
# 	fbq('track', "PageView");
# </script>
# <noscript><img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=1613758345606983&ev=PageView&noscript=1"/></noscript>
#
#
# <script>
#   !function(f,b,e,v,n,t,s)
#   {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#   if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#   n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];
#   s.parentNode.insertBefore(t,s)}(window, document,'script',
#   'https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '226880918049905');
#   fbq('track', 'PageView');
# </script>
# <noscript><img height="1" width="1" style="display:none"
#   src="https://www.facebook.com/tr?id=226880918049905&ev=PageView&noscript=1"
# /></noscript>
#
#
# <!-- TSI 18/06/2018 - 31/12/2018 -->
# <script>
#   !function(f,b,e,v,n,t,s)
#   {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#   if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#   n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];
#   s.parentNode.insertBefore(t,s)}(window, document,'script',
#   'https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '171385340201265');
#   fbq('track', 'PageView');
# </script>
# <noscript><img height="1" width="1" style="display:none"
#   src="https://www.facebook.com/tr?id=171385340201265&ev=PageView&noscript=1"
# /></noscript>
#
# <!-- End Facebook Pixel Code -->
#     <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-M3TXWD9');</script>
# <!-- End Google Tag Manager -->
#
# <!-- Google Tag Manager from Ready Planet end 31/12/2019-->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-K2XJFSQ');</script>
# <!-- End Google Tag Manager -->
#
#
# <link type="text/css" rel="stylesheet" href="/styles/gdpr/jquery-eu-cookie-law-popup.css"/>
# <script src="/scripts/gdpr/jquery-eu-cookie-law-popup.js"></script>
# </head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-M3TXWD9"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
# <!-- Google Tag Manager (noscript) from Ready Planet end 31/12/2019 -->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-K2XJFSQ"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
#
# <!-- GDPR Cookie : Start -->
# <div id="cookiesPolicy" class="eupopup eupopup-container">&nbsp;</div>
# <!-- GDPR Cookie : End -->
# <!--[if lt IE 7]>
# <p class="browsehappy">You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> to improve your experience.</p>
# <![endif]-->
#
# <!-- Start header -->
#
#
#
#
#
# <div class="webonly">
#   <!-- Start header -->
#   <div id="mobile-language-sel" class="container mobile-language-selector collapse">
#     <p class="pull-left"><strong>Language :</strong></p>
#     <ul class="pull-right">
#       <li><a href="/set/localeswitching.do?language=th&country=TH&nextpage=http%3A%2F%2Fwww.set.or.th%2Fset%2Fcompanyfinance.do%3Fsymbol%3DAAV%26type%3Dbalance" >ไทย</a></li>
#
#       <li class="last-item"><a href="/set/localeswitching.do?language=en&country=US&nextpage=http%3A%2F%2Fwww.set.or.th%2Fset%2Fcompanyfinance.do%3Fsymbol%3DAAV%26type%3Dbalance" >EN</a></li>
#
#     </ul>
#   </div>
#
#
#   <div class="header" id="header">
#     <div class="container logo_banner">
#       <div class="row">
#         <div class="col-xs-12 col-md-2 col-sm-4 logo_header">
#           <a href="https://www.set.or.th/th/index.html" class="logo-set-th"></a>
#           <ul class="pull-right mini-language-menu visible-xs">
#             <li><a href="#" class="btn btn-link btn-mobile-toggle-language" data-toggle="collapse" data-target="#mobile-language-sel">Language</a></li>
#             <li><a href="#" class="btn btn-link btn-mobile-signin" data-toggle="collapse" data-target="#login-box">ลงชื่อเข้าใช้</a></li>
#           </ul>
#         </div>
#         <div class="col-xs-12 col-sm-8 col-md-10 braner-and-search padding-0">
#           <!-- Top Banner area -->
#           <div class="visible-lg braner-header">
#             <!-- Start dfp code -->
# <script type='text/javascript'>
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# (function () {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#         '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
# })();
# </script>
#
# <script type='text/javascript'>
# googletag.cmd.push(function () {
#     googletag.defineSlot('/15511860/SET_TH_top_banner_728x90', [728, 90], 'div-gpt-ad-1330935727550-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
# });
# </script>
# <!-- End dfp code -->
# <!-- SET_TH_top_banner_728x90 -->
# <div class="personalized-top-banner" style="display:none;">
# <div id='div-gpt-ad-1330935727550-0' style="width:728px; height:90px;">
# 	<script type='text/javascript'>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1330935727550-0'); });</script>
# </div>
# </div>
#           </div>
#           <div id="nav-form-search" class="search_header navbar-collapse collapse">
#             <form class="form-search" role="form" action="https://www.set.or.th/commons/searchresult.html" id="cse-search-box" target="_blank">
#               <input type="hidden" name="cx" value="partner-pub-0901699256947485:8450636272" />
#               <input type="hidden" name="cof" value="FORID:9" />
#               <input type="hidden" name="ie" value="UTF-8" />
#               <input type="hidden" type="submit" name="sa" value="&#x0e04;&#x0e49;&#x0e19;&#x0e2b;&#x0e32;" />
#               <div class="input-group">
#                 <input type="text" class="input-search form-control not_focus " placeholder="Search" value="Search" name="q">
#                                 <span class="input-group-btn">
#                                     <button class="btn btn-default btn-search" type="button" onclick="javascript:submit();"><i class="fa fa-search"></i></button>
#                                 </span>
#               </div>
#             </form>
#             <div class="row">
#               <div class="col-md-12 search_lan_select hidden-xs">
#                 Language&nbsp;:&nbsp;
#                 <a href="/set/localeswitching.do?language=th&country=TH&nextpage=http%3A%2F%2Fwww.set.or.th%2Fset%2Fcompanyfinance.do%3Fsymbol%3DAAV%26type%3Dbalance" >ไทย</a>&nbsp;|&nbsp;
#
#
#                 <a href="/set/localeswitching.do?language=en&country=US&nextpage=http%3A%2F%2Fwww.set.or.th%2Fset%2Fcompanyfinance.do%3Fsymbol%3DAAV%26type%3Dbalance" >EN</a>&nbsp;
#
#
#
#                 <div class="sr-only"></div>
#                 <div class="pull-right"><a href="#" onclick="window.print();" class="printer-th" title="พิมพ์หน้านี้"></a></div>
#               </div>
#             </div>
#           </div>
#           <div class="nav-get-f visible-xs visible-sm clearfix">
#             <form role="search" action="" onsubmit="quoteActionGotoPage();return false;">
#               <div class="pull-left">
#                 <input type="text" placeholder="Get Quote" value="Get Quote" id="txtSymbolXS">
#               </div>
#               <div class="pull-right">
#                 <button type="button" class="btn-search" id="searchBtnXS" onclick="quoteActionGotoPage();"><i class="fa fa-caret-right"></i></button>
#                 <button type="button" id="quoteBtn2" onclick="window.location='https://www.set.or.th/set/commonslookup.do?language=th&amp;country=TH';">
#                 <small>
#                   ชื่อย่อ
#                 </small>
#                 </button>
#               </div>
#             </form>
#           </div>
#         </div>
#       </div>
#     </div>
#     <!-- Start Nav header -->
#     <nav id="top-nav" class="navbar border-bottom-yellow-4" role="navigation">
#       <div class="container">
#         <div class="row background-nav-tablet ">
#           <div class="navbar-header">
#             <button type="button" class="navbar-toggle collapsed navbar-toggle-show" data-toggle="collapse" data-target="#nav-header">
#               <div class="icon-container">
#                 <span class="sr-only">Toggle navigation</span>
#                 <span class="icon-bar icon-bar-menu"></span>
#                 <span class="icon-bar icon-bar-menu"></span>
#                 <span class="icon-bar icon-bar-menu"></span>
#               </div>
#               <span class="icon-text">MENU</span>
#             </button>
#             <button type="button" class="btn btn-link btn-toggle-search visible-xs" data-toggle="collapse" data-target="#nav-form-search">
#               <i class="fa fa-search"></i>
#             </button>
#             <a class="navbar-brand" href="https://www.set.or.th/th/index.html"></a>
#           </div>
#           <!-- Collect the nav links, forms, and other content for toggling -->
#           <div class="collapse navbar-collapse padding-right-0" id="nav-header">
#
#
#               <ul class="nav navbar-nav">
# 	<li class="nav1 dropdown dropdown-nav"><a class="dropdown-toggle" data-hover="dropdown" data-toggle="dropdown" href="https://www.set.or.th/th/about/index.html"><span class="visible-xs visible-sm">เกี่ยวกับตลท.</span></a>
# 	<ul class="dropdown-menu dropdown-nav-ul">
# 		<li><a href="https://www.set.or.th/th/about/vision/vision_p1.html">พันธกิจและวิสัยทัศน์</a></li>
# 		<li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/th/about/overview/history_p1.html">ภาพรวม ตลท.</a>
# 		<ul class="dropdown-menu popover-set navtop" role="menu">
# 			<li><a href="https://www.set.or.th/th/about/overview/history_p1.html">ประวัติและบทบาท</a></li>
# 			<li><a href="https://www.set.or.th/th/about/overview/board_p1.html">คณะกรรมการ</a></li>
# 			<li><a href="https://www.set.or.th/th/about/overview/organization_p1.html">คณะผู้บริหาร/โครงสร้าง</a></li>
# 			<li><a href="https://www.set.or.th/th/about/overview/setlogo_p1.html">ตราสัญลักษณ์ ตลท.</a></li>
# 			<li><a href="https://www.set.or.th/th/about/overview/setgroup_p1.html">กลุ่มตลาดหลักทรัพย์</a></li>
# 			<li><a href="https://www.set.or.th/th/about/overview/share_p1.html">โครงสร้างการถือหุ้น</a></li>
# 			<li><a href="https://www.set.or.th/th/about/overview/setcg_p1.html">การกำกับดูแลกิจการที่ดี</a></li>
# 			<li><a href="https://www.set.or.th/th/about/overview/whistleblowing_p1.html">การแจ้งเบาะแส</a></li>
# 			<li><a href="http://www.tfex.co.th/th/about/glance.html" target="_blank">เกี่ยวกับตลาดสัญญาซื้อขายล่วงหน้า</a></li>
# 		</ul>
# 		</li>
# 		<li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/th/about/annual/annual_p1.html">รายงานผลการดำเนินงาน</a>
# 		<ul class="dropdown-menu popover-set navtop" role="menu">
# 			<li><a href="https://www.set.or.th/th/about/annual/annual_p1.html">รายงานประจำปี</a></li>
# 			<li><a href="https://www.set.or.th/th/about/annual/sd_report_p1.html">รายงานความยั่งยืน</a></li>
# 			<li><a href="https://www.set.or.th/th/about/annual/financial_statement_p1.html">งบการเงินประจำปีและ MD&amp;A</a></li>
# 		</ul>
# 		</li>
# 		<li><a href="https://www.set.or.th/set/holiday.do?language=th&amp;country=TH">วันหยุดตลาดหลักทรัพย์</a></li>
# 		<li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/th/about/jobs/jobs_p1.html">ร่วมงานกับเรา</a>
# 		<ul class="dropdown-menu popover-set navtop" role="menu">
# 			<li><a href="https://www.set.or.th/th/about/jobs/jobs_p1.html">สมัครงาน</a></li>
# 			<li><a href="https://www.set.or.th/th/about/jobs/internship_p1.html">การฝึกงาน</a></li>
# 			<li><a href="https://www.set.or.th/th/about/jobs/scholarship_p1.html">ทุนการศึกษา</a></li>
# 		</ul>
# 		</li>
# 		<li><a href="https://www.set.or.th/th/about/map/map_p1.html">แผนที่ตลาดหลักทรัพย์</a></li>
# 		<li><a href="https://www.set.or.th/th/about/newsletter/newsletter_p1.html">SET Newsletter</a></li>
# 		<li><a href="https://www.set.or.th/set/setInfographic.do?language=th&country=TH"> SET Infographic</a></li>
# 		<li><a href="https://www.set.or.th/th/about/sse/guideline_p1.html">การพัฒนาตลท.เพื่อความยั่งยืน</a></li>
# 	</ul>
# 	</li>
# 	<li class="nav2 dropdown dropdown-nav"><a class="dropdown-toggle" data-hover="dropdown" data-toggle="dropdown" href="https://www.set.or.th/th/regulations/index.html"><span class="visible-xs visible-sm">กฎเกณฑ์/การกำกับ</span></a>
# 	<ul class="dropdown-menu dropdown-nav-ul">
# 		<li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/th/regulations/supervision/listed_p1.html">หลักเกณฑ์และการกำกับ</a>
# 		<ul class="dropdown-menu popover-set navtop" role="menu">
# 			<li><a href="https://www.set.or.th/th/regulations/supervision/listed_p1.html">การกำกับบริษัทจดทะเบียน</a></li>
# 			<li><a href="https://www.set.or.th/th/regulations/supervision/surveillance_p1.html">การกำกับการซื้อขาย</a></li>
# 			<li><a href="https://www.set.or.th/th/regulations/supervision/member_p1.html">การกำกับบริษัทสมาชิก </a></li>
# 			<li><a href="https://www.set.or.th/th/regulations/supervision/enforcement_p1.html">วินัยและคดี</a></li>
# 			<li><a href="https://www.set.or.th/th/regulations/supervision/market_policy_p1.html">นโยบายกำกับตลาด</a></li>
# 		</ul>
# 		</li>
# 		<li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/rulebook/#/regulation">กฎเกณฑ์</a>
# 		<ul class="dropdown-menu popover-set navtop" role="menu">
# 			<li><a href="https://www.set.or.th/rulebook/#/regulation" target="_blank">กฎเกณฑ์ (Rulebooks)</a></li>
#             <li><a href="https://www.set.or.th/rulebook/#/circular" target="_blank">หนังสือเวียน</a></li>
# 			<li><a href="https://www.set.or.th/rulebook/#/form" target="_blank">แบบฟอร์ม</a></li>
#             <li><a href="https://www.set.or.th/rulebook/#/advancedSearch" target="_blank">Advanced Search</a></li>
#             <!--<li><a href="https://www.set.or.th/th/regulations/rule_amendments/rule_amendments_p1.html">กฎเกณฑ์ใหม่</a></li>-->
#             <li><a href="https://www.set.or.th/th/regulations/simplified_regulations/simplified_regulations_p1.html">Simplified Regulations</a></li>
# 			<li><a href="https://www.set.or.th/th/regulations/disclosure_checklist/download_p1.html">Checklist การเปิดเผยสารสนเทศ</a></li>
# 			<li><a href="https://www.set.or.th/th/regulations/smart_disclosure_program/live.html">โครงการ Smart Disclosure Program</a></li>
# 		</ul>
# 		</li>
# 		<li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/th/regulations/enforcement/enforcement_p1.html">การบังคับใช้</a>
# 		<ul class="dropdown-menu popover-set navtop" role="menu">
# 			<li><a href="https://www.set.or.th/th/regulations/enforcement/enforcement_p1.html">กระบวนการพิจารณา</a></li>
# 			<li><a href="https://www.set.or.th/th/regulations/enforcement/disprocess_p1.html">กระบวนการพิจารณาความผิดทางวินัย</a></li>
# 			<li><a href="https://www.set.or.th/th/regulations/enforcement/aplprocess_p1.html">กระบวนการพิจารณาอุทธรณ์</a></li>
# 			<li><a href="https://www.set.or.th/th/regulations/enforcement/penalties_p1.html">การดำเนินการทางวินัย</a></li>
# 		</ul>
# 		</li>
# 		<li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/th/regulations/tax/tax_p1.html">ภาษี</a>
# 		<ul class="dropdown-menu popover-set navtop" role="menu">
# 			<li><a href="https://www.set.or.th/th/regulations/tax/tax_p1.html">ตราสารทุน</a></li>
# 			<li><a href="https://www.set.or.th/th/regulations/tax/tax_bond_p1.html">ตราสารหนี้</a></li>
# 		</ul>
# 		</li>
# 		<li><a href="https://www.set.or.th/th/regulations/protection/protection_p1.html">การคุ้มครองผู้ลงทุน</a></li>
# 		<li><a href="https://www.set.or.th/th/regulations/consult/market_consultation_p1.html">Market Consultation </a></li>
# 		<li class="dropdown-submenu">
#                 <a href="https://www.set.or.th/set/regulatorystatistics.do?language=th&country=TH" data-toggle="dropdown" aria-expanded="false">ค่าสถิติงานกำกับ</a>
#                 <ul class="dropdown-menu popover-set navtop" role="menu">
#                     <li><a href="https://www.set.or.th/set/regulatorystatistics.do?language=th&country=TH">ค่าสถิติงานกำกับ</a></li>
#                     <li><a href="https://www.set.or.th/th/regulations/statistics/causes_statistics_p1.html">สาเหตุการขึ้นเครื่องหมาย SP ปี 2560 และปี 2561</a></li>
#                 </ul>
#         </li>
# 	</ul>
# 	</li>
# 	<li class="nav3 dropdown dropdown-nav"><a class="dropdown-toggle" data-hover="dropdown" data-toggle="dropdown" href="https://www.set.or.th/th/products/index.html"><span class="visible-xs visible-sm">สินค้า/บริการ</span></a>
# 	<ul class="dropdown-menu dropdown-nav-ul">
# 		<li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/th/products/index/setindex_p1.html">ดัชนี</a>
# 		<ul class="dropdown-menu popover-set navtop" role="menu">
# 			<li><a href="https://www.set.or.th/th/products/index/setindex_p1.html">ดัชนีตลาดหลักทรัพย์</a></li>
# 			<li><a href="https://www.set.or.th/th/products/index/maiindex_p1.html">ดัชนี mai</a></li>
# 			<li><a href="https://www.set.or.th/th/products/index/ftse_set_p1.html">ดัชนี FTSE SET </a></li>
# 			<li><a href="https://www.set.or.th/th/products/index/ftse_asean_p1.html">ดัชนี FTSE ASEAN</a></li>
# 			<li><a href="https://www.set.or.th/th/products/index/tri_p1.html">ดัชนีผลตอบแทนรวม (TRI)</a></li>
# 		</ul>
# 		</li>
# 		<li><a href="https://www.set.or.th/th/products/equities/equities_p1.html">ตราสารทุน</a></li>
# 		<li><a href="https://www.set.or.th/th/products/bonds/bonds_p1.html">ตราสารหนี้</a></li>
# 		<li><a href="http://www.tfex.co.th/th/products/products.html" target="_blank">ตราสารอนุพันธ์</a></li>
# 		<li><a href="https://www.set.or.th/set/etfstatistics.do?language=th&amp;country=TH">อีทีเอฟ (ETF)</a></li>
# 		<li class="dropdown-submenu">
#                 <a href="http://www.thaimutualfund.com" data-toggle="dropdown" aria-expanded="false">กองทุนรวม</a>
#                 <ul class="dropdown-menu popover-set navtop" role="menu">
#                     <li><a href
a>
# 		<ul class="dropdown-menu popover-set navtop" role="menu">
# 			<li><a href="https://www.set.or.th/financialplanning/index.html">หน้าหลัก</a></li>
# 			<!--<li><a href="#">4 รู้สู่ความมั่งคั่ง</a></li>-->
# 			<li><a href="https://www.set.or.th/set/financialplanning/lifeevent.do?groupMenuId=1&amp;name=wealth">เส้นทางมั่งคั่ง</a></li>
# 			<li><a href="https://www.set.or.th/set/financialplanning/lifeevent.do?groupMenuId=2&amp;name=lifeevent">วางแผนตามใจ</a></li>
# 			<li><a href="https://www.set.or.th/set/financialplanning/faq.do?language=th&amp;country=TH">FAQ </a></li>
# 			<li><a href="https://www.set.or.th/set/financialplanning/glossary.do?language=th&amp;country=TH">คำศัพท์น่ารู้</a></li>
# 			<li><a href="https://www.set.or.th/set/financialplanning/lifeevent.do?name=happymoneyworkplace&language=th&country=TH">In-house Training</a></li>
# 		</ul>
# 		</li>
# 		<li class="dropdown-submenu">
#               <a href="https://www.set.or.th/education/th/index.html">เรียนรู้การลงทุน</a>
#               <ul class="dropdown-menu popover-set navtop" role="menu">
#                 <li><a href="https://www.set.or.th/education/th/index.html">หน้าหลัก</a></li>
#                 <li><a href="https://www.set.or.th/set/education/html.do?name=begin&showTitle=F">มือใหม่เริ่มลงทุน</a></li>
#                 <li><a href="https://www.set.or.th/set/education/html.do?name=stock&showTitle=F">ทางเลือกลงทุน</a></li>
#                 <li><a href="https://www.set.or.th/set/education/html.do?name=decode_begin&innerMenuId=17&groupMenuId=3">ถอดรหัสลับการลงทุน</a></li>
#                 <li><a href="https://www.set.or.th/set/education/html.do?name=inv_classroom&showTitle=F">หลักสูตรการอบรม/สัมมนา</a></li>
# 				<li><a href="https://www.set.or.th/set/onlineseminar.do?language=th&country=TH">สัมมนาออนไลน์</a></li>
#                 <li><a href="https://www.set.or.th/set/knowledgeclip.do">คลิปความรู้</a></li>
#                 <li><a href="https://www.set.or.th/elearning" target="_blank">e-Learning</a></li>
#                 <li><a href="https://www.set.or.th/set/article.do">บทความ</a></li>
#                 <li><a href="https://www.set.or.th/set/publicpaper.do?topicId=50&language=th&country=TH">เอกสารเผยแพร่</a></li>
#                 <li><a href="https://www.set.or.th/set/education/html.do?name=calculator_tools&showTitle=F">โปรแกรมคำนวณ</a></li>
#                 <li><a href="https://www.set.or.th/set/infographic.do?language=th&country=TH">Infographic</a></li>
#                 <li><a href="https://www.set.or.th/set/education/glossary.do?language=th&country=TH">คำศัพท์ลงทุน</a></li>
#               </ul>
#             </li>
# 		<li><a href="http://www.maruey.com" target="_blank">ห้องสมุดมารวย</a></li>
# 		<li><a href="http://investory.set.or.th" target="_blank">INVESTORY</a></li>
# 		<li><a href="https://www.set.or.th/setbook/index.html">SET Book</a></li>
# 		<li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/education/th/project/index.html">กิจกรรม/โครงการ </a>
# 		<ul class="dropdown-menu popover-set navtop" role="menu">
# 			<li><a href="https://www.set.or.th/education/th/project/project.html">หน้าหลัก</a></li>
# 			<li><a href="https://www.set.or.th/yfs/index.html" target="_blank">Young Financial Star Competition (YFS)</a></li>
# 			<li><a href="https://www.set.or.th/phetecon/index.html" target="_blank">เศรษฐศาสตร์เพชรยอดมงกุฎฯ</a></li>
# 			<li><a href="https://www.set.or.th/newbreed/index.html" target="_blank">New Breed</a></li>
# 			<li><a href="https://www.set.or.th/youngcfo/index.html" target="_blank">Young CFO</a></li>
# 		</ul>
# 		</li>
# 		<li><a href="https://www.set.or.th/professional/index.html" target="_blank">มุมผู้ประกอบวิชาชีพ</a></li>
# 		<li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/enterprise/home.html">ห้องเรียนผู้ประกอบการ</a>
# 		<ul class="dropdown-menu popover-set navtop" role="menu">
# 			<li><a href="https://www.set.or.th/enterprise/home.html">หน้าหลัก</a></li>
# 			<li><a href="https://www.set.or.th/enterprise/home.html">ช่องทางการเรียนรู้</a></li>
# 			<li><a href="https://www.set.or.th/enterprise/training.html">อบรม / สัมมนา</a></li>
# 			<li><a href="https://www.set.or.th/set/enterprise/activity.do">ภาพกิจกรรม</a></li>
# 			<li><a href="https://www.set.or.th/enterprise/home.html">เส้นทางการเติบโตทางธุรกิจ</a></li>
# 		</ul>
# 		</li>
# 	</ul>
# 	</li>
# 	<!--
#     <li class="nav7 dropdown dropdown-nav" >
#         <a href="https://www.set.or.th/education/th/index.html" class="dropdown-toggle" data-toggle="dropdown" data-hover="dropdown"><span class="visible-xs visible-sm">ห้องเรียนนักลงทุน</span></a>
#         <ul class="dropdown-menu dropdown-nav-ul">
#             <li><a href="https://www.set.or.th/education/th/index.html">หน้าหลัก</a></li>
# 			<li class="dropdown-submenu">
#                 <a href="https://www.set.or.th/education/th/start/index.html" data-toggle="dropdown" aria-expanded="false">เริ่มต้นวางแผนการเงิน</a>
#                 <ul class="dropdown-menu popover-set navtop" role="menu">
#                     <li><a href="https://www.set.or.th/education/th/start/start.html">เริ่มต้นวางแผนการเงิน</a></li>
#                 </ul>
#             </li>
#             <li class="dropdown-submenu">
#                 <a href="https://www.set.or.th/education/th/begin/index.html" data-toggle="dropdown" aria-expanded="false">มือใหม่ลงทุน</a>
#                 <ul class="dropdown-menu popover-set navtop" role="menu">
#                     <li><a href="https://www.set.or.th/education/th/begin/begin.html">มือใหม่ลงทุนอย่างมั่นใจ </a></li>
#                     <li><a href="https://www.set.or.th/education/th/begin/stock.html">ลงทุนหุ้น </a></li>
#                     <li><a href="https://www.set.or.th/education/th/begin/derivatives.html">ลงทุนอนุพันธ์</a></li>
#                     <li><a href="https://www.set.or.th/education/th/begin/etf.html">ลงทุนอีทีเอฟ</a></li>
# ...
#                 </ul>
#             </li>
#             <li><a href="https://www.set.or.th/streaming">Opportunity Day & Company Highlights</a>
#                 <ul class="footer-submenu">
#                     <li><a href="https://www.set.or.th/streaming">Opportunity Day</a></li>
#                     <li><a href="https://www.set.or.th/set/companysummary.do?language=th&country=TH">สรุปข้อสนเทศบริษัทจดทะเบียน</a></li>
#                     <li><a href="https://www.set.or.th/th/company/document/document_p1.html">Stock Focus</a></li>
#                 </ul>
#             </li>
#         </ul>
#     </li>
#     <li><a href="https://www.set.or.th/mai/th/index.html">หน่วยงาน</a>
#         <ul>
#             <li><a href="https://www.set.or.th/mai/th/index.html">ตลาด mai</a>
#                 <ul class="footer-submenu">
#                     <li><a href="https://www.set.or.th/mai/th/about/vision.html">เกี่ยวกับ mai</a></li>
#         <div class="footer-col-3 footer-social ">
#             <div class="footer-body-menu">
#                 <ul class="footer-body-menu-ul">
#                     <li><i class="fa fa-globe"></i><a href="https://www.set.or.th/setresearch" target="_blank">SET Research</a></li>
# 					<li><i class="fa fa-cog"></i><a href="https://www.set.or.th/education/th/online_classroom/tool.html" target="_blank">เครื่องมือการเงินออนไลน์</a></li>
#                     <li><i class="fa fa-graduation-cap"></i><a href="https://www.set.or.th/education/th/online_classroom/index.html" target="_blank">ห้องเรียนออนไลน์ </a></li>
#                     <li><i class="fa fa-play-circle-o"></i><a href="https://www.youtube.com/user/setgroupofficial" target="_blank">VIDEO CENTER (เริ่มต้น/มือใหม่/มือโปร)</a></li>
#                     <li><i class="fa fa-facebook"></i><a href="https://www.facebook.com/set.or.th" target="_blank">www.facebook.com/set.or.th</a></li>
#                     <li><i class="fa fa-twitter"></i><a href="https://twitter.com/SET_Thailand" target="_blank">TWITTER @SET_Thailand</a></li>
#                     <li><i class="fa fa-youtube-play"></i><a href="https://www.youtube.com/user/setgroupofficial" target="_blank">Youtube.com/setgroupofficial</a></li>
#                     <li><i class="fa fa-rss"></i><a href="https://www.set.or.th/th/rss/rss_p1.html" target="_blank">RSS Feed</a></li>
#                 </ul>
# 				<ul class="footer-body-menu-ul">
# 					<li><a href="https://www.set.or.th/th/faqs/web_p1.html" target="_blank">ถาม - ตอบ</a>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; | <a href="https://www.set.or.th/th/contact/contact.html" target="_blank">ติดต่อเรา</a><br><a href="https://www.set.or.th/th/links/setgroup_website.html" target="_blank">เว็บไซต์น่าสนใจ</a>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; | <a href="https://www.set.or.th/th/sitemap/sitemap_p1.html" target="_blank">แผนผังเว็บไซต์</a></li>
#                 </ul>
#             </div>
#         </div>
#     </div>
#     </div>
# </div>
#
#         <div class="container-fluid footer-bottom">
#     <div class="container">
#         <div class="row ">
#     ตลาดหลักทรัพย์แห่งประเทศไทย | สงวนลิขสิทธิ์ <br> เนื้อหาทั้งหมดบนเว็บไซต์นี้ มีขึ้นเพื่อวัตถุประสงค์ในการให้ข้อมูลและเพื่อการศึกษาเท่านั้น ตลาดหลักทรัพย์ฯ มิได้ให้การรับรองและขอปฏิเสธต่อความรับผิดใด ๆ ในเว็บไซต์นี้ <br>
#  <strong><a href="https://www.set.or.th/th/terms-and-conditions.html" target="_blank">ข้อตกลงและเงื่อนไขการใช้งานเว็บไซต์</a> | <a href="https://www.set.or.th/th/privacy-policy.html" target="_blank">นโยบายคุ้มครองข้อมูลส่วนบุคคล</a> | <a href="https://www.set.or.th/th/cookies_policy.html" target="_blank">นโยบายการใช้คุกกี้</a></strong>
#         </div>
#     </div>
# </div>
# <a href="#header" id ="backToTopBtn" class="gototop btn-set-rollover btn-set-upx2"></a>
#
#
#         <div id="showTruehit" class="truehit">
#             <!-- BEGIN WEB STAT CODE -->
#             <script language="javascript1.1"> page="th - Companies - Financial Statement";</script>
#             <script type="text/javascript">
# 	  (function() {
# 		  var ga = document.createElement('script'); ga.type = 'text/javascript';
# 		  ga.async = true;
# 		  ga.src = "//lvs.truehits.in.th/dataa/c0002486.js";
# 		  var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# 	  })();
# </script>
# <script>
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 	ga('create', 'UA-426404-1', 'auto');
# //	ga('send', 'pageview');
# </script>
#
#             <!-- END WEB STAT CODE -->
#         </div>
#     </footer>
#     <!-- End footer -->
#
#     <script type="text/javascript" src="/scripts/socialmedia/facebook-module.js" />
# <!--[if lt IE 9]>
# <script type="text/javascript">
# 	//IE8 bind method hack
# 	if (!Function.prototype.bind) {
# 		Function.prototype.bind = function(oThis) {
# 			if ( typeof this !== 'function') {
# 				// closest thing possible to the ECMAScript 5
# 				// internal IsCallable function
# 				throw new TypeError('Function.prototype.bind - what is trying to be bound is not callable');
# 			}
#
# 			var aArgs = Array.prototype.slice.call(arguments, 1), fToBind = this, fNOP = function() {
# 			}, fBound = function() {
# 				return fToBind.apply(this instanceof fNOP && oThis ? this : oThis, aArgs.concat(Array.prototype.slice.call(arguments)));
# 			};
#
# 			fNOP.prototype = this.prototype;
# 			fBound.prototype = new fNOP();
#
# 			return fBound;
# 		};
# 	}
# </script>
# <![endif]-->
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js"></script>
# <script>
# 	window.jQuery || document.write('<script src="/scripts/vendor/jquery-1.11.2.min.js"><\/script>')
# </script>
#
# <script src="/scripts/vendor/bootstrap.min.js"></script>
# <script src="/scripts/bootstrap-submenu.min.js"></script>
# <script type="text/javascript">
# 	$('.dropdown-submenu > a').submenupicker();
# </script>
# <script src="/scripts/bootstrap-hover-dropdown.min.js"></script>
# <script src="/scripts/bootstrap-tabcollapse.js"></script>
# <!-- GSAP -->
# <script src="/scripts/gsap/TweenLite.min.js"></script>
# <script src="/scripts/gsap/easing/EasePack.min.js"></script>
# <script src="/scripts/gsap/jquery.gsap.min.js"></script>
# <script src="/scripts/gsap/plugins/CSSPlugin.min.js"></script>
# <script src="/scripts/plugins.js"></script>
# <script src="/scripts/main.js"></script>
# <script src="/scripts/jQuery.XDomainRequest.js"></script>
# <script src="/scripts/orientationchange.js"></script>
#
#
#
#
#             <!-- Manage Navigation -->
#             <script language="javascript">
#                 var menu_id = '502001';
#                 var orderMenu = 'company';
#             </script>
#
#
#                 <script src="/scripts/menu/allLeftMenu-th.js"></script>
#
#             <script src="/scripts/menu/genNavigation.js"></script>
#             <script type="text/javascript">
#                 readmenuvar();
#                 leftnav('accordion');
#                 generateBreadCrumbs('breadcrumbs');
#             </script>
#             <!-- End Navigation -->
#
#
#
#
#
#
#
#
#
#
# <link href="/styles/chat.css" rel="stylesheet">
# <div class="fb-customerchat" page_id="95359944974" theme_color="#faae2f"></div>
# <div class="select-chatbot-panel">
#     <div class="live-chat-header">
#         <span onclick="closeChatPanel()">X</span>
#     </div>
#     <div class="live-chat-body">
#         <div class="live-btn">
#             <div>
#                 SET Chatbot : ถามตอบเรื่องการลงทุน  24 ชั่วโมง
#             </div>
#             <div class="chatbot-link-container">
#                 <button class="chatbot-link" onclick="openChatBot()">
#                     เลือก SET Chatbot กด
#                 </button>
#             </div>
#         </div>
#         <div class="chatbot-btn">
#             <div>
#                 สอบถามข้อมูลอื่นๆ กับเจ้าหน้าที่ ในวันทำการ เวลา 8.00 - 18.00 น.
#             </div>
#             <div class="chatbot-link-container">
#                 <button class="chatbot-link" onclick="openLiveChat()">
#                     SET LiveChat กด
#                 </button>
#             </div>
#         </div>
#     </div>
# </div>
# <div class="chat-media">
#     <div class="chat-layout">
#         <div class="chat-container">
#             <button class="button-close" onclick="closeChatMedia()">
#                 <img class="icon-close" src="/images/chat/times.png">
#             </button>
#             <div class="chat-title">สวัสดี&nbsp;
#
#
#                     วันพุธ
#
#             </div>
#             <div class="chat-detail">
#                 <p class="chat-detail-text"></p>
#                 <a class="chat-detail-link" href="#" target="_blank"><button class="button-now">คลิกที่นี่</button></a>
#             </div>
#         </div>
#     </div>
# </div>
# <div class="chatbot-icon">
#     <a href="javascript:openChatSelection()">
#         <img src="/images/icon_chat_b.png"/>
#     </a>
# </div>
# <script src="/scripts/chat.js"></script>
# <!-- Start of LiveChat (www.livechatinc.com) code -->
# <script type="text/javascript">
#   window.__lc = window.__lc || {};
#   window.__lc.license = 7604291;
#   (function() {
#     var lc = document.createElement('script'); lc.type = 'text/javascript'; lc.async = true;
#     lc.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'cdn.livechatinc.com/tracking.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(lc, s);
#   })();
#   window.__lc.visitor = {
#     name: '',
#     email: ''
#   };
# </script>
# <!-- End of LiveChat code -->
#
# </div>
# <!-- End Bottom Zone -->
#
# </body>
# </html>

# %%
print(type(mystr))
# Out:
# <class 'str'>

# %%
from html.parser import HTMLParser
from html.entities import name2codepoint

class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):
        print("Start tag:", tag)
        for attr in attrs:
            print("     attr:", attr)

    def handle_endtag(self, tag):
        print("End tag  :", tag)

    def handle_data(self, data):
        print("Data     :", data)

    def handle_entityref(self, name):
        c = chr(name2codepoint[name])
        print("Named ent:", c)

    def handle_charref(self, name):
        if name.startswith('x'):
            c = chr(int(name[1:], 16))
        else:
            c = chr(int(name))
        print("Num ent  :", c)

    def handle_decl(self, data):
        print("Decl     :", data)

parser = MyHTMLParser()
parser.feed(mystr)
# Out:
# Data     :
#
# Decl     : DOCTYPE html
# Data     :
#
# Start tag: html
#      attr: ('lang', 'th')
# Data     :
#
# Comment  : [if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="th"> <![endif]
# Data     :
#
# Comment  : [if IE 7]> <html class="no-js lt-ie9 lt-ie8" lang="th"> <![endif]
# Data     :
#
# Comment  : [if IE 8]> <html class="no-js lt-ie9" lang="th"> <![endif]
# Data     :
#
# Comment  : [if gt IE 8]><!
# Data     :
# Start tag: html
#      attr: ('class', 'no-js')
#      attr: ('lang', 'th')
# Data     :
# Comment  : <![endif]
# Data     :
#
# Start tag: head
# Data     :
#
# Start tag: meta
#      attr: ('charset', 'utf-8')
# Data     :
#
# Start tag: meta
#      attr: ('http-equiv', 'X-UA-Compatible')
#      attr: ('content', 'IE=edge,chrome=1,IE=8')
# Data     :
#
# Start tag: meta
#      attr: ('name', 'description')
#      attr: ('content', "The Stock Exchange of Thailand: Your Investment Resource for Thailand's Capital Market")
# Data     :
#
# Start tag: meta
#      attr: ('name', 'keywords')
#      attr: ('content', 'SET, mai, thai stocks, Thailand, stock, stock exchange, Thai capital market, equity, bond, derivatives, stock market, quotes, financial, internet trading, listed companies, IPO, regulations, broker, market data, investment information, news, investor education')
# Data     :
#
# Start tag: meta
#      attr: ('name', 'viewport')
#      attr: ('content', 'width=device-width, initial-scale=1, user-scalable=yes')
# Data     :
#
#
#
#
# Start tag: title
# Data     : ตลาดหลักทรัพย์แห่งประเทศไทย - ข้อมูลรายบริษัท/หลักทรัพย์
# End tag  : title
# Data     :
#
#
# Start tag: link
#      attr: ('rel', 'shortcut icon')
#      attr: ('href', '/images/favicon.ico')
#      attr: ('type', 'image/vnd.microsoft.icon')
# End tag  : link
# Data     :
#
# Start tag: link
#      attr: ('rel', 'stylesheet')
#      attr: ('href', '/styles/bootstrap.min.css')
# Data     :
#
# Start tag: link
#      attr: ('rel', 'stylesheet')
#      attr: ('href', '/styles/bootstrap-theme.min.css')
# Data     :
#
# Start tag: link
#      attr: ('rel', 'stylesheet')
#      attr: ('href', '/styles/font-awesome.min.css')
# Data     :
#
# Start tag: link
#      attr: ('rel', 'stylesheet')
#      attr: ('href', '/styles/bootstrap-submenu.min.css')
# Data     :
#
# Start tag: link
#      attr: ('rel', 'stylesheet')
#      attr: ('href', '/styles/main.css')
# Data     :
#
# Start tag: link
#      attr: ('rel', 'stylesheet')
#      attr: ('href', '/styles/main-en.css')
# Data     :
#
# Start tag: link
#      attr: ('rel', 'stylesheet')
#      attr: ('href', '/styles/setstyle.css')
# Data     :
#
# Start tag: link
#      attr: ('rel', 'stylesheet')
#      attr: ('href', '/styles/main-responsive.css')
# Data     :
#
# Start tag: link
#      attr: ('rel', 'stylesheet')
#      attr: ('href', '/styles/tablet.css')
# Data     :
#
# Start tag: link
#      attr: ('rel', 'stylesheet')
#      attr: ('href', '/scripts/fullcalendar-2.1.1/fullcalendar.min.css')
# Data     :
#
# Comment  : [if lt IE 10]><link rel="stylesheet" href="/styles/ie.css"> <![endif]
# Data     :
#
# Start tag: script
#      attr: ('src', '/scripts/vendor/jquery-1.11.2.min.js')
# End tag  : script
# Data     :
#
# Comment  :  Start Other CSS
# Data     :
#
# Comment  :  Start Chart CSS
# Data     :
#
# Start tag: link
#      attr: ('rel', 'stylesheet')
#      attr: ('href', '/styles/chart.css')
# Data     :
#
# Comment  :  End Chart CSS
# Data     :
#
# Comment  :  End Other CSS
# Data     :
#
# Comment  : [if lt IE 9]>
#     <script src="/scripts/vendor/html5shiv.min.js"></script>
#     <script src="/scripts/vendor/modernizr-2.6.2-respond-1.1.0.min.js"></script>
#     <![endif]
# Data     :
#
#
#
#
#
# Start tag: script
# Data     :
#     dataLayer = [{"content_group":"company"}];
#
# End tag  : script
# Data     :
#
#
#
#
# Comment  :  Facebook Pixel Code
# Data     :
#
# Start tag: script
# Data     :
# 	!function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# 			n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# 		n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# 		t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# 			document,'script','https://connect.facebook.net/en_US/fbevents.js');
#
# 	fbq('init', '1613758345606983');
# 	fbq('track', "PageView");
#
# End tag  : script
# Data     :
#
# Start tag: noscript
# Start tag: img
#      attr: ('height', '1')
#      attr: ('width', '1')
#      attr: ('style', 'display:none')
#      attr: ('src', 'https://www.facebook.com/tr?id=1613758345606983&ev=PageView&noscript=1')
# End tag  : img
# End tag  : noscript
# Data     :
#
#
#
# Start tag: script
# Data     :
#   !function(f,b,e,v,n,t,s)
#   {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#   if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#   n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];
#   s.parentNode.insertBefore(t,s)}(window, document,'script',
#   'https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '226880918049905');
#   fbq('track', 'PageView');
#
# End tag  : script
# Data     :
#
# Start tag: noscript
# Start tag: img
#      attr: ('height', '1')
#      attr: ('width', '1')
#      attr: ('style', 'display:none')
#      attr: ('src', 'https://www.facebook.com/tr?id=226880918049905&ev=PageView&noscript=1')
# End tag  : img
# End tag  : noscript
# Data     :
#
#
#
# Comment  :  TSI 18/06/2018 - 31/12/2018
# Data     :
#
# Start tag: script
# Data     :
#   !function(f,b,e,v,n,t,s)
#   {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#   if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#   n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];
#   s.parentNode.insertBefore(t,s)}(window, document,'script',
#   'https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '171385340201265');
#   fbq('track', 'PageView');
#
# End tag  : script
# Data     :
#
# Start tag: noscript
# Start tag: img
#      attr: ('height', '1')
#      attr: ('width', '1')
#      attr: ('style', 'display:none')
#      attr: ('src', 'https://www.facebook.com/tr?id=171385340201265&ev=PageView&noscript=1')
# End tag  : img
# End tag  : noscript
# Data     :
#
#
# Comment  :  End Facebook Pixel Code
# Data     :
#
# Comment  :  Google Tag Manager
# Data     :
#
# Start tag: script
# Data     : (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-M3TXWD9');
# End tag  : script
# Data     :
#
# Comment  :  End Google Tag Manager
# Data     :
#
#
# Comment  :  Google Tag Manager from Ready Planet end 31/12/2019
# Data     :
#
# Start tag: script
# Data     : (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-K2XJFSQ');
# End tag  : script
# Data     :
#
# Comment  :  End Google Tag Manager
# Data     :
#
#
#
# Start tag: link
#      attr: ('type', 'text/css')
#      attr: ('rel', 'stylesheet')
#      attr: ('href', '/styles/gdpr/jquery-eu-cookie-law-popup.css')
# End tag  : link
# Data     :
#
# Start tag: script
#      attr: ('src', '/scripts/gdpr/jquery-eu-cookie-law-popup.js')
# End tag  : script
# Data     :
#
# End tag  : head
# Data     :
#
# Start tag: body
# Data     :
#
# Comment  :  Google Tag Manager (noscript)
# Data     :
#
# Start tag: noscript
# Start tag: iframe
#      attr: ('src', 'https://www.googletagmanager.com/ns.html?id=GTM-M3TXWD9')
#      attr: ('height', '0')
#      attr: ('width', '0')
#      attr: ('style', 'display:none;visibility:hidden')
# End tag  : iframe
# End tag  : noscript
# Data     :
#
# Comment  :  End Google Tag Manager (noscript)
# Data     :
#
#
# Comment  :  Google Tag Manager (noscript) from Ready Planet end 31/12/2019
# Data     :
#
# Start tag: noscript
# Start tag: iframe
#      attr: ('src', 'https://www.googletagmanager.com/ns.html?id=GTM-K2XJFSQ')
#      attr: ('height', '0')
#      attr: ('width', '0')
#      attr: ('style', 'display:none;visibility:hidden')
# End tag  : iframe
# End tag  : noscript
# Data     :
#
# Comment  :  End Google Tag Manager (noscript)
# Data     :
#
#
#
# Comment  :  GDPR Cookie : Start
# Data     :
#
# Start tag: div
#      attr: ('id', 'cookiesPolicy')
#      attr: ('class', 'eupopup eupopup-container')
# Data     :
# End tag  : div
# Data     :
#
# Comment  :  GDPR Cookie : End
# Data     :
#
# Comment  : [if lt IE 7]>
# <p class="browsehappy">You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> to improve your experience.</p>
# <![endif]
# Data     :
#
#
# Comment  :  Start header
# Data     :
#
#
#
#
#
#
# Start tag: div
#      attr: ('class', 'webonly')
# Data     :
#
# Comment  :  Start header
# Data     :
#
# Start tag: div
#      attr: ('id', 'mobile-language-sel')
#      attr: ('class', 'container mobile-language-selector collapse')
# Data     :
#
# Start tag: p
#      attr: ('class', 'pull-left')
# Start tag: strong
# Data     : Language :
# End tag  : strong
# End tag  : p
# Data     :
#
# Start tag: ul
#      attr: ('class', 'pull-right')
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', '/set/localeswitching.do?language=th&country=TH&nextpage=http%3A%2F%2Fwww.set.or.th%2Fset%2Fcompanyfinance.do%3Fsymbol%3DAAV%26type%3Dbalance')
# Data     : ไทย
# End tag  : a
# End tag  : li
# Data     :
#
#
# Start tag: li
#      attr: ('class', 'last-item')
# Start tag: a
#      attr: ('href', '/set/localeswitching.do?language=en&country=US&nextpage=http%3A%2F%2Fwww.set.or.th%2Fset%2Fcompanyfinance.do%3Fsymbol%3DAAV%26type%3Dbalance')
# Data     : EN
# End tag  : a
# End tag  : li
# Data     :
#
#
# End tag  : ul
# Data     :
#
# End tag  : div
# Data     :
#
#
#
# Start tag: div
#      attr: ('class', 'header')
#      attr: ('id', 'header')
# Data     :
#
# Start tag: div
#      attr: ('class', 'container logo_banner')
# Data     :
#
# Start tag: div
#      attr: ('class', 'row')
# Data     :
#
# Start tag: div
#      attr: ('class', 'col-xs-12 col-md-2 col-sm-4 logo_header')
# Data     :
#
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/index.html')
#      attr: ('class', 'logo-set-th')
# End tag  : a
# Data     :
#
# Start tag: ul
#      attr: ('class', 'pull-right mini-language-menu visible-xs')
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', '#')
#      attr: ('class', 'btn btn-link btn-mobile-toggle-language')
#      attr: ('data-toggle', 'collapse')
#      attr: ('data-target', '#mobile-language-sel')
# Data     : Language
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', '#')
#      attr: ('class', 'btn btn-link btn-mobile-signin')
#      attr: ('data-toggle', 'collapse')
#      attr: ('data-target', '#login-box')
# Data     : ลงชื่อเข้าใช้
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# End tag  : div
# Data     :
#
# Start tag: div
#      attr: ('class', 'col-xs-12 col-sm-8 col-md-10 braner-and-search padding-0')
# Data     :
#
# Comment  :  Top Banner area
# Data     :
#
# Start tag: div
#      attr: ('class', 'visible-lg braner-header')
# Data     :
#
# Comment  :  Start dfp code
# Data     :
#
# Start tag: script
#      attr: ('type', 'text/javascript')
# Data     :
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# (function () {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#         '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
# })();
#
# End tag  : script
# Data     :
#
#
# Start tag: script
#      attr: ('type', 'text/javascript')
# Data     :
# googletag.cmd.push(function () {
#     googletag.defineSlot('/15511860/SET_TH_top_banner_728x90', [728, 90], 'div-gpt-ad-1330935727550-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
# });
#
# End tag  : script
# Data     :
#
# Comment  :  End dfp code
# Data     :
#
# Comment  :  SET_TH_top_banner_728x90
# Data     :
#
# Start tag: div
#      attr: ('class', 'personalized-top-banner')
#      attr: ('style', 'display:none;')
# Data     :
#
# Start tag: div
#      attr: ('id', 'div-gpt-ad-1330935727550-0')
#      attr: ('style', 'width:728px; height:90px;')
# Data     :
#
# Start tag: script
#      attr: ('type', 'text/javascript')
# Data     : googletag.cmd.push(function() { googletag.display('div-gpt-ad-1330935727550-0'); });
# End tag  : script
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
#
# Start tag: div
#      attr: ('id', 'nav-form-search')
#      attr: ('class', 'search_header navbar-collapse collapse')
# Data     :
#
# Start tag: form
#      attr: ('class', 'form-search')
#      attr: ('role', 'form')
#      attr: ('action', 'https://www.set.or.th/commons/searchresult.html')
#      attr: ('id', 'cse-search-box')
#      attr: ('target', '_blank')
# Data     :
#
# Start tag: input
#      attr: ('type', 'hidden')
#      attr: ('name', 'cx')
#      attr: ('value', 'partner-pub-0901699256947485:8450636272')
# End tag  : input
# Data     :
#
# Start tag: input
#      attr: ('type', 'hidden')
#      attr: ('name', 'cof')
#      attr: ('value', 'FORID:9')
# End tag  : input
# Data     :
#
# Start tag: input
#      attr: ('type', 'hidden')
#      attr: ('name', 'ie')
#      attr: ('value', 'UTF-8')
# End tag  : input
# Data     :
#
# Start tag: input
#      attr: ('type', 'hidden')
#      attr: ('type', 'submit')
#      attr: ('name', 'sa')
#      attr: ('value', 'ค้นหา')
# End tag  : input
# Data     :
#
# Start tag: div
#      attr: ('class', 'input-group')
# Data     :
#
# Start tag: input
#      attr: ('type', 'text')
#      attr: ('class', 'input-search form-control not_focus ')
#      attr: ('placeholder', 'Search')
#      attr: ('value', 'Search')
#      attr: ('name', 'q')
# Data     :
#
# Start tag: span
#      attr: ('class', 'input-group-btn')
# Data     :
#
# Start tag: button
#      attr: ('class', 'btn btn-default btn-search')
#      attr: ('type', 'button')
#      attr: ('onclick', 'javascript:submit();')
# Start tag: i
#      attr: ('class', 'fa fa-search')
# End tag  : i
# End tag  : button
# Data     :
#
# End tag  : span
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : form
# Data     :
#
# Start tag: div
#      attr: ('class', 'row')
# Data     :
#
# Start tag: div
#      attr: ('class', 'col-md-12 search_lan_select hidden-xs')
# Data     :
#                 Language :
#
# Start tag: a
#      attr: ('href', '/set/localeswitching.do?language=th&country=TH&nextpage=http%3A%2F%2Fwww.set.or.th%2Fset%2Fcompanyfinance.do%3Fsymbol%3DAAV%26type%3Dbalance')
# Data     : ไทย
# End tag  : a
# Data     :  |
#
#
#
# Start tag: a
#      attr: ('href', '/set/localeswitching.do?language=en&country=US&nextpage=http%3A%2F%2Fwww.set.or.th%2Fset%2Fcompanyfinance.do%3Fsymbol%3DAAV%26type%3Dbalance')
# Data     : EN
# End tag  : a
# Data     :
#
#
#
#
# Start tag: div
#      attr: ('class', 'sr-only')
# End tag  : div
# Data     :
#
# Start tag: div
#      attr: ('class', 'pull-right')
# Start tag: a
#      attr: ('href', '#')
#      attr: ('onclick', 'window.print();')
#      attr: ('class', 'printer-th')
#      attr: ('title', 'พิมพ์หน้านี้')
# End tag  : a
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
#
# Start tag: div
#      attr: ('class', 'nav-get-f visible-xs visible-sm clearfix')
# Data     :
#
# Start tag: form
#      attr: ('role', 'search')
#      attr: ('action', '')
#      attr: ('onsubmit', 'quoteActionGotoPage();return false;')
# Data     :
#
# Start tag: div
#      attr: ('class', 'pull-left')
# Data     :
#
# Start tag: input
#      attr: ('type', 'text')
#      attr: ('placeholder', 'Get Quote')
#      attr: ('value', 'Get Quote')
#      attr: ('id', 'txtSymbolXS')
# Data     :
#
# End tag  : div
# Data     :
#
# Start tag: div
#      attr: ('class', 'pull-right')
# Data     :
#
# Start tag: button
#      attr: ('type', 'button')
#      attr: ('class', 'btn-search')
#      attr: ('id', 'searchBtnXS')
#      attr: ('onclick', 'quoteActionGotoPage();')
# Start tag: i
#      attr: ('class', 'fa fa-caret-right')
# End tag  : i
# End tag  : button
# Data     :
#
# Start tag: button
#      attr: ('type', 'button')
#      attr: ('id', 'quoteBtn2')
#      attr: ('onclick', "window.location='https://www.set.or.th/set/commonslookup.do?language=th&country=TH';")
# Data     :
#
# Start tag: small
# Data     :
#                   ชื่อย่อ
#
# End tag  : small
# Data     :
#
# End tag  : button
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : form
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
#
# Comment  :  Start Nav header
# Data     :
#
# Start tag: nav
#      attr: ('id', 'top-nav')
#      attr: ('class', 'navbar border-bottom-yellow-4')
#      attr: ('role', 'navigation')
# Data     :
#
# Start tag: div
#      attr: ('class', 'container')
# Data     :
#
# Start tag: div
#      attr: ('class', 'row background-nav-tablet ')
# Data     :
#
# Start tag: div
#      attr: ('class', 'navbar-header')
# Data     :
#
# Start tag: button
#      attr: ('type', 'button')
#      attr: ('class', 'navbar-toggle collapsed navbar-toggle-show')
#      attr: ('data-toggle', 'collapse')
#      attr: ('data-target', '#nav-header')
# Data     :
#
# Start tag: div
#      attr: ('class', 'icon-container')
# Data     :
#
# Start tag: span
#      attr: ('class', 'sr-only')
# Data     : Toggle navigation
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'icon-bar icon-bar-menu')
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'icon-bar icon-bar-menu')
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'icon-bar icon-bar-menu')
# End tag  : span
# Data     :
#
# End tag  : div
# Data     :
#
# Start tag: span
#      attr: ('class', 'icon-text')
# Data     : MENU
# End tag  : span
# Data     :
#
# End tag  : button
# Data     :
#
# Start tag: button
#      attr: ('type', 'button')
#      attr: ('class', 'btn btn-link btn-toggle-search visible-xs')
#      attr: ('data-toggle', 'collapse')
#      attr: ('data-target', '#nav-form-search')
# Data     :
#
# Start tag: i
#      attr: ('class', 'fa fa-search')
# End tag  : i
# Data     :
#
# End tag  : button
# Data     :
#
# Start tag: a
#      attr: ('class', 'navbar-brand')
#      attr: ('href', 'https://www.set.or.th/th/index.html')
# End tag  : a
# Data     :
#
# End tag  : div
# Data     :
#
# Comment  :  Collect the nav links, forms, and other content for toggling
# Data     :
#
# Start tag: div
#      attr: ('class', 'collapse navbar-collapse padding-right-0')
#      attr: ('id', 'nav-header')
# Data     :
#
#
#
# Start tag: ul
#      attr: ('class', 'nav navbar-nav')
# Data     :
#
# Start tag: li
#      attr: ('class', 'nav1 dropdown dropdown-nav')
# Start tag: a
#      attr: ('class', 'dropdown-toggle')
#      attr: ('data-hover', 'dropdown')
#      attr: ('data-toggle', 'dropdown')
#      attr: ('href', 'https://www.set.or.th/th/about/index.html')
# Start tag: span
#      attr: ('class', 'visible-xs visible-sm')
# Data     : เกี่ยวกับตลท.
# End tag  : span
# End tag  : a
# Data     :
#
# Start tag: ul
#      attr: ('class', 'dropdown-menu dropdown-nav-ul')
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/about/vision/vision_p1.html')
# Data     : พันธกิจและวิสัยทัศน์
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
#      attr: ('class', 'dropdown-submenu')
# Start tag: a
#      attr: ('aria-expanded', 'false')
#      attr: ('data-toggle', 'dropdown')
#      attr: ('href', 'https://www.set.or.th/th/about/overview/history_p1.html')
# Data     : ภาพรวม ตลท.
# End tag  : a
# Data     :
#
# Start tag: ul
#      attr: ('class', 'dropdown-menu popover-set navtop')
#      attr: ('role', 'menu')
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/about/overview/history_p1.html')
# Data     : ประวัติและบทบาท
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/about/overview/board_p1.html')
# Data     : คณะกรรมการ
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/about/overview/organization_p1.html')
# Data     : คณะผู้บริหาร/โครงสร้าง
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/about/overview/setlogo_p1.html')
# Data     : ตราสัญลักษณ์ ตลท.
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/about/overview/setgroup_p1.html')
# Data     : กลุ่มตลาดหลักทรัพย์
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/about/overview/share_p1.html')
# Data     : โครงสร้างการถือหุ้น
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/about/overview/setcg_p1.html')
# Data     : การกำกับดูแลกิจการที่ดี
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/about/overview/whistleblowing_p1.html')
# Data     : การแจ้งเบาะแส
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'http://www.tfex.co.th/th/about/glance.html')
#      attr: ('target', '_blank')
# Data     : เกี่ยวกับตลาดสัญญาซื้อขายล่วงหน้า
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# End tag  : li
# Data     :
#
# Start tag: li
#      attr: ('class', 'dropdown-submenu')
# Start tag: a
#      attr: ('aria-expanded', 'false')
#      attr: ('data-toggle', 'dropdown')
#      attr: ('href', 'https://www.set.or.th/th/about/annual/annual_p1.html')
# Data     : รายงานผลการดำเนินงาน
# End tag  : a
# Data     :
#
# Start tag: ul
#      attr: ('class', 'dropdown-menu popover-set navtop')
#      attr: ('role', 'menu')
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/about/annual/annual_p1.html')
# Data     : รายงานประจำปี
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/about/annual/sd_report_p1.html')
# Data     : รายงานความยั่งยืน
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/about/annual/financial_statement_p1.html')
# Data     : งบการเงินประจำปีและ MD&A
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/set/holiday.do?language=th&country=TH')
# Data     : วันหยุดตลาดหลักทรัพย์
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
#      attr: ('class', 'dropdown-submenu')
# Start tag: a
#      attr: ('aria-expanded', 'false')
#      attr: ('data-toggle', 'dropdown')
#      attr: ('href', 'https://www.set.or.th/th/about/jobs/jobs_p1.html')
# Data     : ร่วมงานกับเรา
# End tag  : a
# Data     :
#
# Start tag: ul
#      attr: ('class', 'dropdown-menu popover-set navtop')
#      attr: ('role', 'menu')
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/about/jobs/jobs_p1.html')
# Data     : สมัครงาน
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/about/jobs/internship_p1.html')
# Data     : การฝึกงาน
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/about/jobs/scholarship_p1.html')
# Data     : ทุนการศึกษา
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/about/map/map_p1.html')
# Data     : แผนที่ตลาดหลักทรัพย์
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/about/newsletter/newsletter_p1.html')
# Data     : SET Newsletter
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/set/setInfographic.do?language=th&country=TH')
# Data     :  SET Infographic
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/about/sse/guideline_p1.html')
# Data     : การพัฒนาตลท.เพื่อความยั่งยืน
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# End tag  : li
# Data     :
#
# Start tag: li
#      attr: ('class', 'nav2 dropdown dropdown-nav')
# Start tag: a
#      attr: ('class', 'dropdown-toggle')
#      attr: ('data-hover', 'dropdown')
#      attr: ('data-toggle', 'dropdown')
#      attr: ('href', 'https://www.set.or.th/th/regulations/index.html')
# Start tag: span
#      attr: ('class', 'visible-xs visible-sm')
# Data     : กฎเกณฑ์/การกำกับ
# End tag  : span
# End tag  : a
# Data     :
#
# Start tag: ul
#      attr: ('class', 'dropdown-menu dropdown-nav-ul')
# Data     :
#
# Start tag: li
#      attr: ('class', 'dropdown-submenu')
# Start tag: a
#      attr: ('aria-expanded', 'false')
#      attr: ('data-toggle', 'dropdown')
#      attr: ('href', 'https://www.set.or.th/th/regulations/supervision/listed_p1.html')
# Data     : หลักเกณฑ์และการกำกับ
# End tag  : a
# Data     :
#
# Start tag: ul
#      attr: ('class', 'dropdown-menu popover-set navtop')
#      attr: ('role', 'menu')
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/regulations/supervision/listed_p1.html')
# Data     : การกำกับบริษัทจดทะเบียน
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/regulations/supervision/surveillance_p1.html')
# Data     : การกำกับการซื้อขาย
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/regulations/supervision/member_p1.html')
# Data     : การกำกับบริษัทสมาชิก
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/regulations/supervision/enforcement_p1.html')
# Data     : วินัยและคดี
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/regulations/supervision/market_policy_p1.html')
# Data     : นโยบายกำกับตลาด
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# End tag  : li
# Data     :
#
# Start tag: li
#      attr: ('class', 'dropdown-submenu')
# Start tag: a
#      attr: ('aria-expanded', 'false')
#      attr: ('data-toggle', 'dropdown')
#      attr: ('href', 'https://www.set.or.th/rulebook/#/regulation')
# Data     : กฎเกณฑ์
# End tag  : a
# Data     :
#
# Start tag: ul
#      attr: ('class', 'dropdown-menu popover-set navtop')
#      attr: ('role', 'menu')
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/rulebook/#/regulation')
#      attr: ('target', '_blank')
# Data     : กฎเกณฑ์ (Rulebooks)
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/rulebook/#/circular')
#      attr: ('target', '_blank')
# Data     : หนังสือเวียน
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/rulebook/#/form')
#      attr: ('target', '_blank')
# Data     : แบบฟอร์ม
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/rulebook/#/advancedSearch')
#      attr: ('target', '_blank')
# Data     : Advanced Search
# End tag  : a
# End tag  : li
# Data     :
#
# Comment  : <li><a href="https://www.set.or.th/th/regulations/rule_amendments/rule_amendments_p1.html">กฎเกณฑ์ใหม่</a></li>
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/regulations/simplified_regulations/simplified_regulations_p1.html')
# Data     : Simplified Regulations
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/regulations/disclosure_checklist/download_p1.html')
# Data     : Checklist การเปิดเผยสารสนเทศ
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/regulations/smart_disclosure_program/live.html')
# Data     : โครงการ Smart Disclosure Program
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# End tag  : li
# Data     :
#
# Start tag: li
#      attr: ('class', 'dropdown-submenu')
# Start tag: a
#      attr: ('aria-expanded', 'false')
#      attr: ('data-toggle', 'dropdown')
#      attr: ('href', 'https://www.set.or.th/th/regulations/enforcement/enforcement_p1.html')
# Data     : การบังคับใช้
# End tag  : a
# Data     :
#
# Start tag: ul
#      attr: ('class', 'dropdown-menu popover-set navtop')
#      attr: ('role', 'menu')
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/regulations/enforcement/enforcement_p1.html')
# Data     : กระบวนการพิจารณา
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/regulations/enforcement/disprocess_p1.html')
# Data     : กระบวนการพิจารณาความผิดทางวินัย
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/regulations/enforcement/aplprocess_p1.html')
# Data     : กระบวนการพิจารณาอุทธรณ์
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/regulations/enforcement/penalties_p1.html')
# Data     : การดำเนินการทางวินัย
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# End tag  : li
# Data     :
#
# Start tag: li
#      attr: ('class', 'dropdown-submenu')
# Start tag: a
#      attr: ('aria-expanded', 'false')
#      attr: ('data-toggle', 'dropdown')
#      attr: ('href', 'https://www.set.or.th/th/regulations/tax/tax_p1.html')
# Data     : ภาษี
# End tag  : a
# Data     :
#
# Start tag: ul
#      attr: ('class', 'dropdown-menu popover-set navtop')
#      attr: ('role', 'menu')
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/regulations/tax/tax_p1.html')
# Data     : ตราสารทุน
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/regulations/tax/tax_bond_p1.html')
# Data     : ตราสารหนี้
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/regulations/protection/protection_p1.html')
# Data     : การคุ้มครองผู้ลงทุน
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/regulations/consult/market_consultation_p1.html')
# Data     : Market Consultation
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
#      attr: ('class', 'dropdown-submenu')
# Data     :
#
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/set/regulatorystatistics.do?language=th&country=TH')
#      attr: ('data-toggle', 'dropdown')
#      attr: ('aria-expanded', 'false')
# Data     : ค่าสถิติงานกำกับ
# End tag  : a
# Data     :
#
# Start tag: ul
#      attr: ('class', 'dropdown-menu popover-set navtop')
#      attr: ('role', 'menu')
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/set/regulatorystatistics.do?language=th&country=TH')
# Data     : ค่าสถิติงานกำกับ
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/regulations/statistics/causes_statistics_p1.html')
# Data     : สาเหตุการขึ้นเครื่องหมาย SP ปี 2560 และปี 2561
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# End tag  : li
# Data     :
#
# Start tag: li
#      attr: ('class', 'nav3 dropdown dropdown-nav')
# Start tag: a
#      attr: ('class', 'dropdown-toggle')
#      attr: ('data-hover', 'dropdown')
#      attr: ('data-toggle', 'dropdown')
#      attr: ('href', 'https://www.set.or.th/th/products/index.html')
# Start tag: span
#      attr: ('class', 'visible-xs visible-sm')
# Data     : สินค้า/บริการ
# End tag  : span
# End tag  : a
# Data     :
#
# Start tag: ul
#      attr: ('class', 'dropdown-menu dropdown-nav-ul')
# Data     :
#
# Start tag: li
#      attr: ('class', 'dropdown-submenu')
# Start tag: a
#      attr: ('aria-expanded', 'false')
#      attr: ('data-toggle', 'dropdown')
#      attr: ('href', 'https://www.set.or.th/th/products/index/setindex_p1.html')
# Data     : ดัชนี
# End tag  : a
# Data     :
#
# Start tag: ul
#      attr: ('class', 'dropdown-menu popover-set navtop')
#      attr: ('role', 'menu')
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/index/setindex_p1.html')
# Data     : ดัชนีตลาดหลักทรัพย์
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/index/maiindex_p1.html')
# Data     : ดัชนี mai
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/index/ftse_set_p1.html')
# Data     : ดัชนี FTSE SET
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/index/ftse_asean_p1.html')
# Data     : ดัชนี FTSE ASEAN
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/index/tri_p1.html')
# Data     : ดัชนีผลตอบแทนรวม (TRI)
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/equities/equities_p1.html')
# Data     : ตราสารทุน
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/bonds/bonds_p1.html')
# Data     : ตราสารหนี้
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'http://www.tfex.co.th/th/products/products.html')
#      attr: ('target', '_blank')
# Data     : ตราสารอนุพันธ์
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/set/etfstatistics.do?language=th&country=TH')
# Data     : อีทีเอฟ (ETF)
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
#      attr: ('class', 'dropdown-submenu')
# Data     :
#
# Start tag: a
#      attr: ('href', 'http://www.thaimutualfund.com')
#      attr: ('data-toggle', 'dropdown')
#      attr: ('aria-expanded', 'false')
# Data     : กองทุนรวม
# End tag  : a
# Data     :
#
# Start tag: ul
#      attr: ('class', 'dropdown-menu popover-set navtop')
#      attr: ('role', 'menu')
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'http://www.thaimutualfund.com')
#      attr: ('target', '_blank')
# Data     : Thai Mutual Fund
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', '/th/products/fund/cg_fund.html')
# Data     : CG Fund
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# End tag  : li
# Data     :
#
# Start tag: li
#      attr: ('class', 'dropdown-submenu')
# Start tag: a
#      attr: ('aria-expanded', 'false')
#      attr: ('data-toggle', 'dropdown')
#      attr: ('href', 'https://www.set.or.th/th/products/dw/dw_p1.html')
# Data     : ใบสำคัญแสดงสิทธิอนุพันธ์ (DW)
# End tag  : a
# Data     :
#
# Start tag: ul
#      attr: ('class', 'dropdown-menu popover-set navtop')
#      attr: ('role', 'menu')
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/dw/dw_p1.html')
# Data     : มือใหม่
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/set/newlistingdw.do?language=th&country=TH')
# Data     : มือโปร
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/dw/dw_list.html')
# Data     : ผู้ออก
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# End tag  : li
# Data     :
#
# Start tag: li
#      attr: ('class', 'dropdown-submenu')
# Data     :
#
# Start tag: a
#      attr: ('href', '/th/products/dr/dr_knowledge.html')
#      attr: ('data-toggle', 'dropdown')
#      attr: ('aria-expanded', 'false')
# Data     : ตราสารแสดงสิทธิการฝากหลักทรัพย์ต่างประเทศ (DR)
# End tag  : a
# Data     :
#
# Start tag: ul
#      attr: ('class', 'dropdown-menu popover-set navtop')
#      attr: ('role', 'menu')
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://marketdata.set.or.th/mkt/stocklistbytype.do?type=X&market=A&language=th&country=TH')
# Data     : ราคา DR
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/set/drinformation.do?language=th&country=TH')
# Data     : ข้อมูล DR
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/dr/dr_issuer.html')
# Data     : ข้อมูลผู้ออก DR
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/dr/dr_knowledge.html')
# Data     : ความรู้ผู้ลงทุน
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/dr/dr_faq.html')
# Data     : ถาม-ตอบ
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# End tag  : li
# Data     :
#
# Start tag: li
#      attr: ('class', 'dropdown-submenu')
# Start tag: a
#      attr: ('aria-expanded', 'false')
#      attr: ('data-toggle', 'dropdown')
#      attr: ('href', 'https://www.set.or.th/th/products/info/details_p1.html')
# Data     : บริการข้อมูลหลักทรัพย์
# End tag  : a
# Data     :
#
# Start tag: ul
#      attr: ('class', 'dropdown-menu popover-set navtop')
#      attr: ('role', 'menu')
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/info/details_p1.html')
# Data     : ประเภทของข้อมูล
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/info/subscription_p1.html')
# Data     : ติดต่อรับบริการ
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/info/data_vendors_p1.html')
# Data     : รายชื่อผู้ขายข้อมูลรับอนุญาต
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/info/policy_p1.html')
# Data     : นโยบายการใช้ข้อมูลตลาดหลักทรัพย์
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# End tag  : li
# Data     :
#
# Start tag: li
#      attr: ('class', 'dropdown-submenu')
# Start tag: a
#      attr: ('aria-expanded', 'false')
#      attr: ('data-toggle', 'dropdown')
#      attr: ('href', 'https://www.set.or.th/th/products/listing2/listing_set_p1.html')
# Data     : บริการการเข้าจดทะเบียน
# End tag  : a
# Data     :
#
# Start tag: ul
#      attr: ('class', 'dropdown-menu popover-set navtop')
#      attr: ('role', 'menu')
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/listing2/listing_set_p1.html')
# Data     : การเข้าจดทะเบียนตราสารทุน
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/listing/bond_listing_p1.html')
# Data     : การเข้าจดทะเบียนตราสารหนี้
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/listing2/download_p1.html')
# Data     : แบบฟอร์ม แบบคำขอ และแบบรายงาน
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
# End tag  : li
# Data     :
#
# Start tag: li
#      attr: ('class', 'dropdown-submenu')
# Start tag: a
#      attr: ('aria-expanded', 'false')
#      attr: ('data-toggle', 'dropdown')
#      attr: ('href', 'https://www.set.or.th/th/products/institution/institution_p1.html')
# Data     : บริการสำหรับผู้ลงทุนสถาบัน
# End tag  : a
# Data     :
#
# Start tag: ul
#      attr: ('class', 'dropdown-menu popover-set navtop')
#      attr: ('role', 'menu')
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/institution/institution_p1.html')
# Data     : วิธีการซื้อขายสำหรับผู้ลงทุนสถาบัน
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/institution/dma.html')
# Data     : Direct Market Access (DMA)
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/institution/program_trading.html')
# Data     : Program Trading
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/colocation/colocation_p1.html')
# Data     : บริการ Co-location
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
#      attr: ('class', 'dropdown-submenu')
# Start tag: a
#      attr: ('aria-expanded', 'false')
#      attr: ('data-toggle', 'dropdown')
#      attr: ('href', 'https://www.set.or.th/th/products/trading/equity/trading_p1.html')
# Data     : วิธีการซื้อขาย
# End tag  : a
# Data     :
#
# Start tag: ul
#      attr: ('class', 'dropdown-menu popover-set navtop')
#      attr: ('role', 'menu')
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/trading/equity/trading_p1.html')
# Data     : การซื้อขายตราสารทุน
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/trading/bond/bond_trading_p1.html')
# Data     : การซื้อขายตราสารหนี้
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'http://www.tfex.co.th/th/education/files/2011-09-FiveSteps-Trading-Th.pdf')
#      attr: ('target', '_blank')
# Data     : การซื้อขายตราสารอนุพันธ์
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# End tag  : li
# Data     :
#
# Start tag: li
#      attr: ('class', 'dropdown-submenu')
# Start tag: a
#      attr: ('aria-expanded', 'false')
#      attr: ('data-toggle', 'dropdown')
#      attr: ('href', 'https://www.set.or.th/set/memberlist.do?language=th&country=TH')
# Data     : บริษัทสมาชิก
# End tag  : a
# Data     :
#
# Start tag: ul
#      attr: ('class', 'dropdown-menu popover-set navtop')
#      attr: ('role', 'menu')
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/set/memberlist.do?language=th&country=TH')
# Data     : รายชื่อบริษัทสมาชิกตลาดหลักทรัพย์แห่งประเทศไทย
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/member/firsts/firsts_dealer_p1.html')
# Data     : รายชื่อผู้ค้าตราสารหนี้ในระบบ Firsts
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/member/firsts/firsts_investor_p1.html')
# Data     : รายชื่อผู้ลงทุนสถาบันในระบบ Firsts
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'http://www.tfex.co.th/th/member/list.html')
#      attr: ('target', '_blank')
# Data     : รายชื่อบริษัทสมาชิกตลาดสัญญาซื้อขายล่วงหน้า
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/member/member_stock.html')
# Data     : การรับสมาชิก
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/isv/isv_p1.html')
# Data     : บริษัทผู้พัฒนาระบบ (ISV)
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
#      attr: ('class', 'dropdown-submenu')
# Start tag: a
#      attr: ('aria-expanded', 'false')
#      attr: ('data-toggle', 'dropdown')
#      attr: ('href', 'https://www.set.or.th/th/setapp.html')
# Data     : SET App
# End tag  : a
# Data     :
#
# Start tag: ul
#      attr: ('class', 'dropdown-menu popover-set navtop')
#      attr: ('role', 'menu')
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/setapp.html')
# Data     : ดาวน์โหลด
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/setapp_noti.html')
# Data     : การตั้งค่า Notifications
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', '/th/LINE.html')
# Data     : LINE Official
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/financial/financial_instruments.html')
# Data     : เครื่องมือทางการเงิน
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
#      attr: ('class', 'dropdown-submenu')
# Start tag: a
#      attr: ('aria-expanded', 'false')
#      attr: ('data-toggle', 'dropdown')
#      attr: ('href', 'https://www.set.or.th/th/products/resource/resource_p1.html')
# Data     : แหล่งศึกษาข้อมูล
# End tag  : a
# Data     :
#
# Start tag: ul
#      attr: ('class', 'dropdown-menu popover-set navtop')
#      attr: ('role', 'menu')
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/products/resource/resource_p1.html')
# Data     : แหล่งความรู้การลงทุน
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/setresearch/setresearch.html')
#      attr: ('target', '_blank')
# Data     : SET Research
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/market/MnA.html')
# Data     : การควบรวมกิจการ
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# End tag  : li
# Data     :
#
# Start tag: li
#      attr: ('class', 'dropdown-submenu')
# Data     :
#
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/setresearch/setresearch_p1.html')
#      attr: ('data-toggle', 'dropdown')
#      attr: ('aria-expanded', 'false')
# Data     : SET Research
# End tag  : a
# Data     :
#
# Start tag: ul
#      attr: ('class', 'dropdown-menu popover-set navtop')
#      attr: ('role', 'menu')
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/setresearch/setresearch_p1.html')
# Data     : SET Research
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/setresearch/database/overview.html')
# Data     : Database
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/setresearch/information/press_release.html')
# Data     : Information
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
# ...
# Data     : เปิดตัวหุ้นไอพีโอ
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/news/issuer_activities/setawards/setawards_p1.html')
# Data     : SET Awards
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/news/issuer_activities/recent_seminar/recent_seminar_p1.html')
# Data     : สัมมนาที่ผ่านมา
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/news/set_in_the_city/set_in_the_city_p1.html')
# Data     : SET in the City
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/news/algorithmic_trading/algo_p1.html')
# Data     : Algorithmic Trading
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/news/thailand_focus/thailandfocus_p1.html')
# Data     : Thailand Focus
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'http://www.thaimutualfundnews.com')
#      attr: ('target', '_blank')
# Data     : โครงการ LTF
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/news/csr/csr_p1.html')
# Data     : ความรับผิดชอบต่อสังคม
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/news/download/document_p1.html')
# Data     : เอกสารประกอบการสัมมนา
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# Start tag: div
#      attr: ('class', 'container padding-0')
# Data     :
#
# Start tag: div
#      attr: ('class', 'footer-col-3 footer-social ')
# Data     :
#
# Start tag: div
#      attr: ('class', 'footer-body-menu')
# Data     :
#
# Start tag: ul
#      attr: ('class', 'footer-body-menu-ul')
# Data     :
#
# Start tag: li
# Start tag: i
#      attr: ('class', 'fa fa-globe')
# End tag  : i
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/setresearch')
#      attr: ('target', '_blank')
# Data     : SET Research
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: i
#      attr: ('class', 'fa fa-cog')
# End tag  : i
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/education/th/online_classroom/tool.html')
#      attr: ('target', '_blank')
# Data     : เครื่องมือการเงินออนไลน์
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: i
#      attr: ('class', 'fa fa-graduation-cap')
# End tag  : i
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/education/th/online_classroom/index.html')
#      attr: ('target', '_blank')
# Data     : ห้องเรียนออนไลน์
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: i
#      attr: ('class', 'fa fa-play-circle-o')
# End tag  : i
# Start tag: a
#      attr: ('href', 'https://www.youtube.com/user/setgroupofficial')
#      attr: ('target', '_blank')
# Data     : VIDEO CENTER (เริ่มต้น/มือใหม่/มือโปร)
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: i
#      attr: ('class', 'fa fa-facebook')
# End tag  : i
# Start tag: a
#      attr: ('href', 'https://www.facebook.com/set.or.th')
#      attr: ('target', '_blank')
# Data     : www.facebook.com/set.or.th
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: i
#      attr: ('class', 'fa fa-twitter')
# End tag  : i
# Start tag: a
#      attr: ('href', 'https://twitter.com/SET_Thailand')
#      attr: ('target', '_blank')
# Data     : TWITTER @SET_Thailand
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: i
#      attr: ('class', 'fa fa-youtube-play')
# End tag  : i
# Start tag: a
#      attr: ('href', 'https://www.youtube.com/user/setgroupofficial')
#      attr: ('target', '_blank')
# Data     : Youtube.com/setgroupofficial
# End tag  : a
# End tag  : li
# Data     :
#
# Start tag: li
# Start tag: i
#      attr: ('class', 'fa fa-rss')
# End tag  : i
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/rss/rss_p1.html')
#      attr: ('target', '_blank')
# Data     : RSS Feed
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# Start tag: ul
#      attr: ('class', 'footer-body-menu-ul')
# Data     :
#
# Start tag: li
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/faqs/web_p1.html')
#      attr: ('target', '_blank')
# Data     : ถาม - ตอบ
# End tag  : a
# Data     :       |
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/contact/contact.html')
#      attr: ('target', '_blank')
# Data     : ติดต่อเรา
# End tag  : a
# Start tag: br
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/links/setgroup_website.html')
#      attr: ('target', '_blank')
# Data     : เว็บไซต์น่าสนใจ
# End tag  : a
# Data     :       |
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/sitemap/sitemap_p1.html')
#      attr: ('target', '_blank')
# Data     : แผนผังเว็บไซต์
# End tag  : a
# End tag  : li
# Data     :
#
# End tag  : ul
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
#
#
# Start tag: div
#      attr: ('class', 'container-fluid footer-bottom')
# Data     :
#
# Start tag: div
#      attr: ('class', 'container')
# Data     :
#
# Start tag: div
#      attr: ('class', 'row ')
# Data     :
#     ตลาดหลักทรัพย์แห่งประเทศไทย | สงวนลิขสิทธิ์
# Start tag: br
# Data     :  เนื้อหาทั้งหมดบนเว็บไซต์นี้ มีขึ้นเพื่อวัตถุประสงค์ในการให้ข้อมูลและเพื่อการศึกษาเท่านั้น ตลาดหลักทรัพย์ฯ มิได้ให้การรับรองและขอปฏิเสธต่อความรับผิดใด ๆ ในเว็บไซต์นี้
# Start tag: br
# Data     :
#
# Start tag: strong
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/terms-and-conditions.html')
#      attr: ('target', '_blank')
# Data     : ข้อตกลงและเงื่อนไขการใช้งานเว็บไซต์
# End tag  : a
# Data     :  |
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/privacy-policy.html')
#      attr: ('target', '_blank')
# Data     : นโยบายคุ้มครองข้อมูลส่วนบุคคล
# End tag  : a
# Data     :  |
# Start tag: a
#      attr: ('href', 'https://www.set.or.th/th/cookies_policy.html')
#      attr: ('target', '_blank')
# Data     : นโยบายการใช้คุกกี้
# End tag  : a
# End tag  : strong
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
#
# Start tag: a
#      attr: ('href', '#header')
#      attr: ('id', 'backToTopBtn')
#      attr: ('class', 'gototop btn-set-rollover btn-set-upx2')
# End tag  : a
# Data     :
#
#
#
# Start tag: div
#      attr: ('id', 'showTruehit')
#      attr: ('class', 'truehit')
# Data     :
#
# Comment  :  BEGIN WEB STAT CODE
# Data     :
#
# Start tag: script
#      attr: ('language', 'javascript1.1')
# Data     :  page="th - Companies - Financial Statement";
# End tag  : script
# Data     :
#
# Start tag: script
#      attr: ('type', 'text/javascript')
# Data     :
# 	  (function() {
# 		  var ga = document.createElement('script'); ga.type = 'text/javascript';
# 		  ga.async = true;
# 		  ga.src = "//lvs.truehits.in.th/dataa/c0002486.js";
# 		  var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# 	  })();
#
# End tag  : script
# Data     :
#
# Start tag: script
# Data     :
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 	ga('create', 'UA-426404-1', 'auto');
# //	ga('send', 'pageview');
#
# End tag  : script
# Data     :
#
#
# Comment  :  END WEB STAT CODE
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : footer
# Data     :
#
# Comment  :  End footer
# Data     :
#
#
# Start tag: script
#      attr: ('type', 'text/javascript')
#      attr: ('src', '/scripts/socialmedia/facebook-module.js')
# End tag  : script
# Data     :
#
# Comment  : [if lt IE 9]>
# <script type="text/javascript">
# 	//IE8 bind method hack
# 	if (!Function.prototype.bind) {
# 		Function.prototype.bind = function(oThis) {
# 			if ( typeof this !== 'function') {
# 				// closest thing possible to the ECMAScript 5
# 				// internal IsCallable function
# 				throw new TypeError('Function.prototype.bind - what is trying to be bound is not callable');
# 			}
#
# 			var aArgs = Array.prototype.slice.call(arguments, 1), fToBind = this, fNOP = function() {
# 			}, fBound = function() {
# 				return fToBind.apply(this instanceof fNOP && oThis ? this : oThis, aArgs.concat(Array.prototype.slice.call(arguments)));
# 			};
#
# 			fNOP.prototype = this.prototype;
# 			fBound.prototype = new fNOP();
#
# 			return fBound;
# 		};
# 	}
# </script>
# <![endif]
# Data     :
#
#
# Start tag: script
#      attr: ('src', '//ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js')
# End tag  : script
# Data     :
#
# Start tag: script
# Data     :
# 	window.jQuery || document.write('<script src="/scripts/vendor/jquery-1.11.2.min.js"><\/script>')
#
# End tag  : script
# Data     :
#
#
# Start tag: script
#      attr: ('src', '/scripts/vendor/bootstrap.min.js')
# End tag  : script
# Data     :
#
# Start tag: script
#      attr: ('src', '/scripts/bootstrap-submenu.min.js')
# End tag  : script
# Data     :
#
# Start tag: script
#      attr: ('type', 'text/javascript')
# Data     :
# 	$('.dropdown-submenu > a').submenupicker();
#
# End tag  : script
# Data     :
#
# Start tag: script
#      attr: ('src', '/scripts/bootstrap-hover-dropdown.min.js')
# End tag  : script
# Data     :
#
# Start tag: script
#      attr: ('src', '/scripts/bootstrap-tabcollapse.js')
# End tag  : script
# Data     :
#
# Comment  :  GSAP
# Data     :
#
# Start tag: script
#      attr: ('src', '/scripts/gsap/TweenLite.min.js')
# End tag  : script
# Data     :
#
# Start tag: script
#      attr: ('src', '/scripts/gsap/easing/EasePack.min.js')
# End tag  : script
# Data     :
#
# Start tag: script
#      attr: ('src', '/scripts/gsap/jquery.gsap.min.js')
# End tag  : script
# Data     :
#
# Start tag: script
#      attr: ('src', '/scripts/gsap/plugins/CSSPlugin.min.js')
# End tag  : script
# Data     :
#
# Start tag: script
#      attr: ('src', '/scripts/plugins.js')
# End tag  : script
# Data     :
#
# Start tag: script
#      attr: ('src', '/scripts/main.js')
# End tag  : script
# Data     :
#
# Start tag: script
#      attr: ('src', '/scripts/jQuery.XDomainRequest.js')
# End tag  : script
# Data     :
#
# Start tag: script
#      attr: ('src', '/scripts/orientationchange.js')
# End tag  : script
# Data     :
#
#
#
#
#
# Comment  :  Manage Navigation
# Data     :
#
# Start tag: script
#      attr: ('language', 'javascript')
# Data     :
#                 var menu_id = '502001';
#                 var orderMenu = 'company';
#
# End tag  : script
# Data     :
#
#
#
# Start tag: script
#      attr: ('src', '/scripts/menu/allLeftMenu-th.js')
# End tag  : script
# Data     :
#
#
# Start tag: script
#      attr: ('src', '/scripts/menu/genNavigation.js')
# End tag  : script
# Data     :
#
# Start tag: script
#      attr: ('type', 'text/javascript')
# Data     :
#                 readmenuvar();
#                 leftnav('accordion');
#                 generateBreadCrumbs('breadcrumbs');
#
# End tag  : script
# Data     :
#
# Comment  :  End Navigation
# Data     :
#
#
#
#
#
#
#
#
#
#
#
# Start tag: link
#      attr: ('href', '/styles/chat.css')
#      attr: ('rel', 'stylesheet')
# Data     :
#
# Start tag: div
#      attr: ('class', 'fb-customerchat')
#      attr: ('page_id', '95359944974')
#      attr: ('theme_color', '#faae2f')
# End tag  : div
# Data     :
#
# Start tag: div
#      attr: ('class', 'select-chatbot-panel')
# Data     :
#
# Start tag: div
#      attr: ('class', 'live-chat-header')
# Data     :
#
# Start tag: span
#      attr: ('onclick', 'closeChatPanel()')
# Data     : X
# End tag  : span
# Data     :
#
# End tag  : div
# Data     :
#
# Start tag: div
#      attr: ('class', 'live-chat-body')
# Data     :
#
# Start tag: div
#      attr: ('class', 'live-btn')
# Data     :
#
# Start tag: div
# Data     :
#                 SET Chatbot : ถามตอบเรื่องการลงทุน  24 ชั่วโมง
#
# End tag  : div
# Data     :
#
# Start tag: div
#      attr: ('class', 'chatbot-link-container')
# Data     :
#
# Start tag: button
#      attr: ('class', 'chatbot-link')
#      attr: ('onclick', 'openChatBot()')
# Data     :
#                     เลือก SET Chatbot กด
#
# End tag  : button
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
#
# Start tag: div
#      attr: ('class', 'chatbot-btn')
# Data     :
#
# Start tag: div
# Data     :
#                 สอบถามข้อมูลอื่นๆ กับเจ้าหน้าที่ ในวันทำการ เวลา 8.00 - 18.00 น.
#
# End tag  : div
# Data     :
#
# Start tag: div
#      attr: ('class', 'chatbot-link-container')
# Data     :
#
# Start tag: button
#      attr: ('class', 'chatbot-link')
#      attr: ('onclick', 'openLiveChat()')
# Data     :
#                     SET LiveChat กด
#
# End tag  : button
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
#
# Start tag: div
#      attr: ('class', 'chat-media')
# Data     :
#
# Start tag: div
#      attr: ('class', 'chat-layout')
# Data     :
#
# Start tag: div
#      attr: ('class', 'chat-container')
# Data     :
#
# Start tag: button
#      attr: ('class', 'button-close')
#      attr: ('onclick', 'closeChatMedia()')
# Data     :
#
# Start tag: img
#      attr: ('class', 'icon-close')
#      attr: ('src', '/images/chat/times.png')
# Data     :
#
# End tag  : button
# Data     :
#
# Start tag: div
#      attr: ('class', 'chat-title')
# Data     : สวัสดี
#
#
#                     วันพุธ
#
#
# End tag  : div
# Data     :
#
# Start tag: div
#      attr: ('class', 'chat-detail')
# Data     :
#
# Start tag: p
#      attr: ('class', 'chat-detail-text')
# End tag  : p
# Data     :
#
# Start tag: a
#      attr: ('class', 'chat-detail-link')
#      attr: ('href', '#')
#      attr: ('target', '_blank')
# Start tag: button
#      attr: ('class', 'button-now')
# Data     : คลิกที่นี่
# End tag  : button
# End tag  : a
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
#
# End tag  : div
# Data     :
#
# Start tag: div
#      attr: ('class', 'chatbot-icon')
# Data     :
#
# Start tag: a
#      attr: ('href', 'javascript:openChatSelection()')
# Data     :
#
# Start tag: img
#      attr: ('src', '/images/icon_chat_b.png')
# End tag  : img
# Data     :
#
# End tag  : a
# Data     :
#
# End tag  : div
# Data     :
#
# Start tag: script
#      attr: ('src', '/scripts/chat.js')
# End tag  : script
# Data     :
#
# Comment  :  Start of LiveChat (www.livechatinc.com) code
# Data     :
#
# Start tag: script
#      attr: ('type', 'text/javascript')
# Data     :
#   window.__lc = window.__lc || {};
#   window.__lc.license = 7604291;
#   (function() {
#     var lc = document.createElement('script'); lc.type = 'text/javascript'; lc.async = true;
#     lc.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'cdn.livechatinc.com/tracking.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(lc, s);
#   })();
#   window.__lc.visitor = {
#     name: '',
#     email: ''
#   };
#
# End tag  : script
# Data     :
#
# Comment  :  End of LiveChat code
# Data     :
#
#
# End tag  : div
# Data     :
#
# Comment  :  End Bottom Zone
# Data     :
#
#
# End tag  : body
# Data     :
#
# End tag  : html

# %%
import time
t = time.localtime()
current_time = time.strftime("year-%y:%m:%d:%H:%M:%S", t)
print(current_time)
# Out:
# 19:10:30:16:07:39

# %%
import datetime
 
currentDT = datetime.datetime.now()
print (str(currentDT))
# Out:
# 2019-10-30 16:10:13.143267

# %%
currentDT1 = datetime.datetime.now()
print (str(currentDT1-currentDT))
# Out:
# 0:01:02.770038
